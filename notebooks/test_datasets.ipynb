# %%
import sys
sys.path.append('..')

import numpy as np
from isegm.data.datasets import ADE20kDataset

dataset = ADE20kDataset('/playpen-raid2/qinliu/data/ADE20k/ADEChallengeData2016')
sample = dataset.get_sample(1)

obj_id = 1
image = sample.image
mask = sample.gt_mask(obj_id)
name = sample.category_name(obj_id)

print(name, mask.shape, image.shape)
# Out:
# floor (512, 711) (512, 711, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
import matplotlib.pyplot as plt
plt.imshow(mask)
