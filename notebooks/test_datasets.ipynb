# %%
import sys
sys.path.append('..')

import numpy as np
from PIL import Image
from torchvision import transforms

array = np.zeros((128, 128, 3)).astype(np.uint8)
image = transforms.ToTensor()(array)

print(array.shape, image.shape)
print(array.dtype, image.dtype)
# Out:
# (128, 128, 3) torch.Size([3, 128, 128])
# uint8 torch.float32

# %%
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
import matplotlib.pyplot as plt
plt.imshow(mask)
